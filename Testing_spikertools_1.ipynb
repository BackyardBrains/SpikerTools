# %%
#clone package repo
# !git clone https://github.com/BackyardBrains/SpikerTools.git

# %cd SpikerTools

# !git pull origin master 


# !pip install -r requirements.txt

#install package
#!python setup.py install

from SpikerTools import spikertools
# Out:
# Cloning into 'SpikerTools'...
# remote: Enumerating objects: 22, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 22 (delta 4), reused 14 (delta 4), pack-reused 7
# Unpacking objects: 100% (22/22), done.
# /content/SpikerTools/SpikerTools/SpikerTools
# fatal: Couldn't find remote ref master
# ...
#   Using cached fonttools-4.28.5-py3-none-any.whl (890 kB)
# ...
#   Using cached matplotlib-3.5.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
# ERROR: Could not find a version that satisfies the requirement NEURON==7.8 (from versions: 7.8.0.119, 7.8.0.127, 7.8.1, 7.8.1.1, 7.8.2, 8.0a0, 8.0.0)
# ERROR: No matching distribution found for NEURON==7.8

# %%
s1 = spikertools.Session("/content/BYB_Recording_2021-06-18_16.14.32.wav")

# %%
s1.plot_overview()

# %%
s1.plot_overview(show_events=False)
